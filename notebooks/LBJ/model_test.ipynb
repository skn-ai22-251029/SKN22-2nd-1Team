# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train_df = pd.read_csv("../../data/processed/train.csv")
test_df = pd.read_csv("../../data/processed/test.csv")

display(train_df.describe())
display(train_df.info())
display(train_df.head())

display(test_df.describe())
display(test_df.info())
display(test_df.head())
# Out:
#              row_id  Administrative  Administrative_Duration  Informational  \
# count   9864.000000     9864.000000              9864.000000    9864.000000
# mean    6144.728609        2.317620                81.241059       0.504663
# std     3560.729013        3.319144               179.610421       1.275169
# min        0.000000        0.000000                 0.000000       0.000000
# 25%     3058.750000        0.000000                 0.000000       0.000000
# 50%     6127.500000        1.000000                 8.000000       0.000000
# 75%     9239.250000        4.000000                93.000000       0.000000
# max    12329.000000       27.000000              3398.750000      24.000000
#
#        Informational_Duration  ProductRelated  ProductRelated_Duration  \
# count             9864.000000     9864.000000              9864.000000
# mean                34.590252       31.452758              1186.546010
# std                141.428972       43.615440              1909.252291
# min                  0.000000        0.000000                 0.000000
# 25%                  0.000000        7.000000               182.566071
# 50%                  0.000000       18.000000               600.536667
# 75%                  0.000000       38.000000              1474.508333
# max               2549.375000      705.000000             63973.522230
#
#        BounceRates    ExitRates   PageValues   SpecialDay  OperatingSystems  \
# count  9864.000000  9864.000000  9864.000000  9864.000000       9864.000000
# mean      0.022396     0.043313     5.944562     0.062693          2.127534
# std       0.048809     0.048901    18.562169     0.201271          0.918098
# min       0.000000     0.000000     0.000000     0.000000          1.000000
# 25%       0.000000     0.014286     0.000000     0.000000          2.000000
# 50%       0.003110     0.025195     0.000000     0.000000          2.000000
# 75%       0.017081     0.050000     0.000000     0.000000          3.000000
# max       0.200000     0.200000   361.763742     1.000000          8.000000
#
#            Browser       Region  TrafficType      Revenue
# count  9864.000000  9864.000000  9864.000000  9864.000000
# mean      2.366788     3.152778     4.071168     0.154704
# std       1.732810     2.395939     4.015231     0.361641
# min       1.000000     1.000000     1.000000     0.000000
# 25%       2.000000     1.000000     2.000000     0.000000
# 50%       2.000000     3.000000     2.000000     0.000000
# 75%       2.000000     4.000000     4.000000     0.000000
# max      13.000000     9.000000    20.000000     1.000000
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9864 entries, 0 to 9863
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   row_id                   9864 non-null   int64
#  1   Administrative           9864 non-null   int64
#  2   Administrative_Duration  9864 non-null   float64
#  3   Informational            9864 non-null   int64
#  4   Informational_Duration   9864 non-null   float64
#  5   ProductRelated           9864 non-null   int64
#  6   ProductRelated_Duration  9864 non-null   float64
#  7   BounceRates              9864 non-null   float64
#  8   ExitRates                9864 non-null   float64
#  9   PageValues               9864 non-null   float64
#  10  SpecialDay               9864 non-null   float64
#  11  Month                    9864 non-null   object
#  12  OperatingSystems         9864 non-null   int64
#  13  Browser                  9864 non-null   int64
#  14  Region                   9864 non-null   int64
#  15  TrafficType              9864 non-null   int64
#  16  VisitorType              9864 non-null   object
#  17  Weekend                  9864 non-null   bool
#  18  Revenue                  9864 non-null   int64
# dtypes: bool(1), float64(7), int64(9), object(2)
# memory usage: 1.4+ MB
# None
#    row_id  Administrative  Administrative_Duration  Informational  \
# 0    4263               8                   732.25              0
# 1    5905               0                     0.00              0
# 2    9434               0                     0.00              0
# 3    3505               2                   338.00              0
# 4    2067               0                     0.00              0
#
#    Informational_Duration  ProductRelated  ProductRelated_Duration  \
# 0                     0.0              34              1345.755952
# 1                     0.0               4               157.200000
# 2                     0.0               4                42.000000
# 3                     0.0              17              1205.566667
# 4                     0.0              32               827.646212
#
#    BounceRates  ExitRates  PageValues  SpecialDay Month  OperatingSystems  \
# 0     0.005128   0.013342   12.274195         0.8   May                 3
# 1     0.040000   0.100000    0.000000         0.0   Oct                 1
# 2     0.000000   0.050000    0.000000         0.0   Dec                 2
# 3     0.012500   0.037500   19.236250         0.8   May                 3
# 4     0.000000   0.000587   54.676348         0.0   Mar                 2
#
#    Browser  Region  TrafficType        VisitorType  Weekend  Revenue
# 0        3       3            2  Returning_Visitor    False        0
# 1        8       3            1  Returning_Visitor     True        0
# 2       10       1            2  Returning_Visitor    False        0
# 3        2       2            2  Returning_Visitor    False        1
# 4        2       7            2  Returning_Visitor    False        1
#              row_id  Administrative  Administrative_Duration  Informational  \
# count   2466.000000     2466.000000              2466.000000    2466.000000
# mean    6243.585564        2.305353                79.128815       0.499189
# std     3554.244812        3.332979               164.992517       1.250152
# min        1.000000        0.000000                 0.000000       0.000000
# 25%     3173.750000        0.000000                 0.000000       0.000000
# 50%     6311.000000        1.000000                 6.500000       0.000000
# 75%     9281.750000        3.000000                93.975000       0.000000
# max    12327.000000       26.000000              2407.423810      14.000000
#
#        Informational_Duration  ProductRelated  ProductRelated_Duration  \
# count             2466.000000     2466.000000              2466.000000
# mean                34.000983       32.846310              1227.547061
# std                138.024375       47.754225              1931.277884
# min                  0.000000        0.000000                 0.000000
# 25%                  0.000000        7.000000               190.627083
# 50%                  0.000000       19.000000               590.568333
# 75%                  0.000000       38.000000              1436.318029
# max               1778.000000      518.000000             27009.859430
#
#        BounceRates    ExitRates   PageValues   SpecialDay  OperatingSystems  \
# count  2466.000000  2466.000000  2466.000000  2466.000000       2466.000000
# mean      0.021375     0.042111     5.668042     0.056367          2.109895
# std       0.047185     0.047355    18.595609     0.189164          0.883754
# min       0.000000     0.000000     0.000000     0.000000          1.000000
# 25%       0.000000     0.014286     0.000000     0.000000          2.000000
# 50%       0.003125     0.025000     0.000000     0.000000          2.000000
# 75%       0.016429     0.050000     0.000000     0.000000          3.000000
# max       0.200000     0.200000   360.953384     1.000000          8.000000
#
#            Browser       Region  TrafficType      Revenue
# count  2466.000000  2466.000000  2466.000000  2466.000000
# mean      2.318329     3.125710     4.063260     0.154907
# std       1.653457     2.424439     4.065495     0.361889
# min       1.000000     1.000000     1.000000     0.000000
# 25%       2.000000     1.000000     2.000000     0.000000
# 50%       2.000000     3.000000     2.000000     0.000000
# 75%       2.000000     4.000000     4.000000     0.000000
# max      13.000000     9.000000    20.000000     1.000000
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2466 entries, 0 to 2465
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   row_id                   2466 non-null   int64
#  1   Administrative           2466 non-null   int64
#  2   Administrative_Duration  2466 non-null   float64
#  3   Informational            2466 non-null   int64
#  4   Informational_Duration   2466 non-null   float64
#  5   ProductRelated           2466 non-null   int64
#  6   ProductRelated_Duration  2466 non-null   float64
#  7   BounceRates              2466 non-null   float64
#  8   ExitRates                2466 non-null   float64
#  9   PageValues               2466 non-null   float64
#  10  SpecialDay               2466 non-null   float64
#  11  Month                    2466 non-null   object
#  12  OperatingSystems         2466 non-null   int64
#  13  Browser                  2466 non-null   int64
#  14  Region                   2466 non-null   int64
#  15  TrafficType              2466 non-null   int64
#  16  VisitorType              2466 non-null   object
#  17  Weekend                  2466 non-null   bool
#  18  Revenue                  2466 non-null   int64
# dtypes: bool(1), float64(7), int64(9), object(2)
# memory usage: 349.3+ KB
# None
#    row_id  Administrative  Administrative_Duration  Informational  \
# 0    4722               1                      4.0              0
# 1    6835               1                     23.2              0
# 2    5524               0                      0.0              0
# 3     663               0                      0.0              0
# 4     136               0                      0.0              0
#
#    Informational_Duration  ProductRelated  ProductRelated_Duration  \
# 0                     0.0              13               161.166667
# 1                     0.0              23               290.000000
# 2                     0.0               6                95.000000
# 3                     0.0               2                17.000000
# 4                     0.0               9               303.666667
#
#    BounceRates  ExitRates  PageValues  SpecialDay Month  OperatingSystems  \
# 0     0.024615   0.061538    0.000000         0.6   May                 2
# 1     0.000000   0.033333    0.000000         0.0   Jul                 2
# 2     0.028571   0.028571   86.336233         0.0   Oct                 1
# 3     0.000000   0.100000    0.000000         0.0   Mar                 1
# 4     0.005556   0.046296    0.000000         0.0   Feb                 2
#
#    Browser  Region  TrafficType        VisitorType  Weekend  Revenue
# 0        5       9            5  Returning_Visitor    False        0
# 1        2       8            3  Returning_Visitor    False        0
# 2        1       4            2        New_Visitor    False        1
# 3        1       8            3  Returning_Visitor    False        0
# 4        4       5            2  Returning_Visitor    False        0

# %%
X_train = train_df.drop("Revenue", axis=1)
y_train = train_df["Revenue"]

X_test = test_df.drop("Revenue", axis=1)
y_test = test_df["Revenue"]

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((9864, 18), (2466, 18), (9864,), (2466,))

# %%
# pip install ucimlrepo pandas scikit-learn numpy joblib

import numpy as np
import pandas as pd
import joblib

from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, RobustScaler
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import (
    roc_auc_score, average_precision_score,
    f1_score, precision_recall_curve,
    confusion_matrix, classification_report
)

RANDOM_STATE = 42
TEST_SIZE = 0.2
MODEL_PATH = "online_shoppers_lr_robust_onehot.joblib"


# 2) Define columns (UCI schema 기준)
numeric_cols = [
    "Administrative", "Administrative_Duration",
    "Informational", "Informational_Duration",
    "ProductRelated", "ProductRelated_Duration",
    "BounceRates", "ExitRates",
    "PageValues", "SpecialDay",
]
categorical_cols = [
    "Month", "OperatingSystems", "Browser", "Region",
    "TrafficType", "VisitorType", "Weekend",
]

# 4) Preprocess (RobustScaler + OneHot)
preprocess = ColumnTransformer(
    transformers=[
        ("num", RobustScaler(), numeric_cols),
        ("cat", OneHotEncoder(handle_unknown="ignore"), categorical_cols),
    ],
    remainder="drop",
)

# 5) Model with class_weight for imbalance
clf = LogisticRegression(
    max_iter=5000,
    solver="saga",           # sparse one-hot에 적합
    class_weight="balanced", # 불균형 가중치
    n_jobs=-1,
)

pipeline = Pipeline(steps=[
    ("preprocess", preprocess),
    ("model", clf),
])

# 6) Fit
pipeline.fit(X_train, y_train)

# 7) Predict / Evaluate
proba = pipeline.predict_proba(X_test)[:, 1]
pred_default = (proba >= 0.5).astype(int)

roc = roc_auc_score(y_test, proba)
prauc = average_precision_score(y_test, proba)  # PR-AUC
f1 = f1_score(y_test, pred_default)

print("=== Evaluation (threshold=0.5) ===")
print(f"ROC-AUC : {roc:.4f}")
print(f"PR-AUC  : {prauc:.4f}")
print(f"F1      : {f1:.4f}")
print("Confusion matrix:\n", confusion_matrix(y_test, pred_default))
print("\nClassification report:\n", classification_report(y_test, pred_default, digits=4))

# (선택) PR 커브 기반으로 F1 최대가 되는 임계값도 같이 출력
prec, rec, thr = precision_recall_curve(y_test, proba)
f1s = 2 * (prec * rec) / (prec + rec + 1e-12)
best_idx = np.nanargmax(f1s)
best_thr = thr[best_idx - 1] if best_idx > 0 else 0.5  # thr 길이가 하나 짧음
print(f"\nBest-F1 threshold (from PR curve): {best_thr:.4f}, F1={f1s[best_idx]:.4f}")

# 8) Extract/Save model (전처리+모델 통째로 저장)
joblib.dump(pipeline, MODEL_PATH)
print(f"\nSaved pipeline to: {MODEL_PATH}")

# 9) (검증) 로드 후 동일 예측 되는지 간단 체크
loaded = joblib.load(MODEL_PATH)
proba2 = loaded.predict_proba(X_test)[:, 1]
print("Reload check (max abs diff in proba):", float(np.max(np.abs(proba - proba2))))
# Out:
# === Evaluation (threshold=0.5) ===
# ROC-AUC : 0.8903
# PR-AUC  : 0.6245
# F1      : 0.6247
# Confusion matrix:
#  [[1865  219]
#  [ 109  273]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9448    0.8949    0.9192      2084
#            1     0.5549    0.7147    0.6247       382
#
#     accuracy                         0.8670      2466
#    macro avg     0.7498    0.8048    0.7719      2466
# weighted avg     0.8844    0.8670    0.8736      2466
#
#
# Best-F1 threshold (from PR curve): 0.5567, F1=0.6321
#
# Saved pipeline to: online_shoppers_lr_robust_onehot.joblib
# Reload check (max abs diff in proba): 0.0
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(

# %%
# pip install matplotlib seaborn

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.metrics import (
    RocCurveDisplay, PrecisionRecallDisplay,
    confusion_matrix
)
from sklearn.calibration import calibration_curve
from sklearn.inspection import permutation_importance

sns.set(style="whitegrid")

# ===== 전제: 이미 아래 변수들이 존재한다고 가정 =====
# pipeline  : 학습된 Pipeline (preprocess + model)
# X_test    : 테스트 피처 (DataFrame)
# y_test    : 테스트 라벨 (0/1)
# proba     : pipeline.predict_proba(X_test)[:, 1]
# pred_default : (proba >= 0.5).astype(int)

# 1) ROC Curve
plt.figure(figsize=(6, 5))
RocCurveDisplay.from_predictions(y_test, proba)
plt.title("ROC Curve")
plt.tight_layout()
plt.show()

# 2) Precision-Recall Curve (불균형에서 중요)
plt.figure(figsize=(6, 5))
PrecisionRecallDisplay.from_predictions(y_test, proba)
plt.title("Precision-Recall Curve")
plt.tight_layout()
plt.show()

# 3) Confusion Matrix (threshold=0.5)
cm = confusion_matrix(y_test, pred_default)
plt.figure(figsize=(5.5, 4.5))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", cbar=False)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix (threshold=0.5)")
plt.tight_layout()
plt.show()

# 4) Calibration Curve (확률이 얼마나 믿을만한지)
prob_true, prob_pred = calibration_curve(y_test, proba, n_bins=10, strategy="quantile")
plt.figure(figsize=(6, 5))
plt.plot(prob_pred, prob_true, marker="o", label="Model")
plt.plot([0, 1], [0, 1], "--", label="Perfectly calibrated")
plt.xlabel("Mean predicted probability")
plt.ylabel("Fraction of positives")
plt.title("Calibration Curve")
plt.legend()
plt.tight_layout()
plt.show()

# 5) Predicted probability distribution (구매/비구매 확률 분포가 갈라지는지)
plt.figure(figsize=(7, 4.5))
sns.kdeplot(proba[y_test == 0], label="Non-purchase (y=0)", fill=True, alpha=0.35)
sns.kdeplot(proba[y_test == 1], label="Purchase (y=1)", fill=True, alpha=0.35)
plt.xlabel("Predicted probability")
plt.title("Predicted Probability Distribution")
plt.legend()
plt.tight_layout()
plt.show()

# 6) Permutation Importance (Pipeline에서도 가능)
#    - OneHot까지 포함한 전체 피처 중요도는 컬럼이 너무 많아질 수 있어서
#      여기서는 “원본 컬럼 단위”로 보고 싶다면 별도 설계가 필요함.
#    - 대신: transformed feature 기준 top-k를 뽑아 보여줌.

# (주의) Pipeline에서 preprocess 결과는 sparse일 수 있음. permutation_importance는 동작하지만 느릴 수 있어.
result = permutation_importance(
    pipeline, X_test, y_test,
    n_repeats=10, random_state=42,
    scoring="average_precision"  # PR-AUC 기반 중요도
)

importances = result.importances_mean
idx = np.argsort(importances)[::-1]

# transformed feature names 얻기
pre = pipeline.named_steps["preprocess"]
feature_names = pre.get_feature_names_out()

top_k = 25
top_idx = idx[:top_k]

plt.figure(figsize=(9, 6))
sns.barplot(x=importances[top_idx], y=np.array(feature_names)[top_idx], orient="h")
plt.title(f"Permutation Importance (Top {top_k}, scoring=PR-AUC)")
plt.xlabel("Mean importance decrease")
plt.ylabel("Feature")
plt.tight_layout()
plt.show()

# %%
# pip install pandas numpy scikit-learn joblib matplotlib seaborn

import numpy as np
import pandas as pd
import joblib

from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, RobustScaler
from sklearn.pipeline import Pipeline

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier, StackingClassifier

from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import (
    f1_score, roc_auc_score, average_precision_score,
    precision_recall_curve, confusion_matrix, classification_report
)

# =========================
# Config
# =========================
TRAIN_PATH = "../../data/processed/train.csv"
TEST_PATH  = "../../data/processed/test.csv"
TARGET_COL = "Revenue"   # 네 csv에서 타깃 컬럼명
MODEL_PATH = "model_stacking_robust_onehot.joblib"
RANDOM_STATE = 42
N_SPLITS = 5

# =========================
# Load
# =========================
train_df = pd.read_csv(TRAIN_PATH)
test_df  = pd.read_csv(TEST_PATH)

if TARGET_COL not in train_df.columns:
    raise ValueError(f"TARGET_COL='{TARGET_COL}' not found in train.csv columns: {list(train_df.columns)}")

X_train = train_df.drop(columns=[TARGET_COL])
y_train = train_df[TARGET_COL].astype(int)  # True/False or 0/1 모두 대응(대부분 int로 변환 가능)

# test에도 라벨이 있다면 평가 가능, 없다면 예측만 가능하게 처리
has_test_label = TARGET_COL in test_df.columns
X_test = test_df.drop(columns=[TARGET_COL]) if has_test_label else test_df.copy()
y_test = test_df[TARGET_COL].astype(int) if has_test_label else None

# =========================
# Column typing (자동 추정)
# =========================
# - 숫자형: number dtype
# - 범주형: object/bool/category
num_cols = X_train.select_dtypes(include=["number"]).columns.tolist()
cat_cols = X_train.select_dtypes(include=["object", "bool", "category"]).columns.tolist()

# (안전) Month가 문자열인데 숫자로 읽혔거나, 반대일 수도 있음 → 필요하면 여기서 수동 지정
# print("num_cols:", num_cols)
# print("cat_cols:", cat_cols)

preprocess = ColumnTransformer(
    transformers=[
        ("num", RobustScaler(), num_cols),
        ("cat", OneHotEncoder(handle_unknown="ignore"), cat_cols),
    ],
    remainder="drop",
)

# =========================
# Models (불균형 weight 적용)
# =========================
lr = LogisticRegression(
    max_iter=5000, solver="saga", class_weight="balanced",
    n_jobs=-1, random_state=RANDOM_STATE
)

rf = RandomForestClassifier(
    n_estimators=400,
    min_samples_leaf=2,
    class_weight="balanced_subsample",
    n_jobs=-1,
    random_state=RANDOM_STATE
)

et = ExtraTreesClassifier(
    n_estimators=600,
    min_samples_leaf=2,
    class_weight="balanced",
    n_jobs=-1,
    random_state=RANDOM_STATE
)

meta = LogisticRegression(
    max_iter=5000, solver="saga", class_weight="balanced",
    n_jobs=-1, random_state=RANDOM_STATE
)

stack = StackingClassifier(
    estimators=[("lr", lr), ("rf", rf), ("et", et)],
    final_estimator=meta,
    stack_method="predict_proba",
    cv=5,
    n_jobs=-1
)

pipeline = Pipeline(steps=[
    ("preprocess", preprocess),
    ("model", stack),
])

# =========================
# 1) OOF 확률로 threshold 튜닝 (train만 사용, 추가 split 없음)
# =========================
skf = StratifiedKFold(n_splits=N_SPLITS, shuffle=True, random_state=RANDOM_STATE)
oof_proba = np.zeros(len(X_train), dtype=float)

for fold, (tr_idx, va_idx) in enumerate(skf.split(X_train, y_train), 1):
    X_tr, y_tr = X_train.iloc[tr_idx], y_train.iloc[tr_idx]
    X_va, y_va = X_train.iloc[va_idx], y_train.iloc[va_idx]

    pipeline.fit(X_tr, y_tr)
    oof_proba[va_idx] = pipeline.predict_proba(X_va)[:, 1]
    print(f"[Fold {fold}] done")

prec, rec, thr = precision_recall_curve(y_train, oof_proba)
f1s = 2 * (prec * rec) / (prec + rec + 1e-12)
best_idx = np.nanargmax(f1s)
best_thr = thr[best_idx - 1] if best_idx > 0 else 0.5
print("\n[OOF] Best threshold:", float(best_thr), "Best F1:", float(f1s[best_idx]))

# =========================
# 2) train 전체로 재학습
# =========================
pipeline.fit(X_train, y_train)

# =========================
# 3) test 평가(라벨 있을 때)
# =========================
test_proba = pipeline.predict_proba(X_test)[:, 1]
test_pred = (test_proba >= best_thr).astype(int)

if has_test_label:
    print("\n=== TEST Metrics (using OOF-tuned threshold) ===")
    print("ROC-AUC :", roc_auc_score(y_test, test_proba))
    print("PR-AUC  :", average_precision_score(y_test, test_proba))
    print("F1      :", f1_score(y_test, test_pred))
    print("Confusion matrix:\n", confusion_matrix(y_test, test_pred))
    print("\nReport:\n", classification_report(y_test, test_pred, digits=4))
else:
    print("\n(test.csv에 Revenue가 없어서 평가 대신 예측만 생성합니다.)")

# =========================
# 4) 모델 추출/저장 (pipeline + threshold 같이 저장)
# =========================
artifact = {
    "pipeline": pipeline,
    "best_threshold": float(best_thr),
    "num_cols": num_cols,
    "cat_cols": cat_cols
}
joblib.dump(artifact, MODEL_PATH)
print("\nSaved:", MODEL_PATH)
# Out:
# [Fold 1] done
# [Fold 2] done
# [Fold 3] done
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [Fold 4] done
# [Fold 5] done
#
# [OOF] Best threshold: 0.7213854387986033 Best F1: 0.6886153846148864
#
# === TEST Metrics (using OOF-tuned threshold) ===
# ROC-AUC : 0.9243990614102964
# PR-AUC  : 0.7290871815396859
# F1      : 0.6666666666666666
# Confusion matrix:
#  [[1934  150]
#  [ 116  266]]
#
# Report:
#                precision    recall  f1-score   support
#
#            0     0.9434    0.9280    0.9357      2084
#            1     0.6394    0.6963    0.6667       382
#
#     accuracy                         0.8921      2466
#    macro avg     0.7914    0.8122    0.8012      2466
# weighted avg     0.8963    0.8921    0.8940      2466
#
#
# Saved: model_stacking_robust_onehot.joblib

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import RocCurveDisplay, PrecisionRecallDisplay, confusion_matrix
from sklearn.calibration import calibration_curve

sns.set(style="whitegrid")

# 전제: y_test, test_proba, test_pred 가 존재해야 함 (test에 Revenue 있을 때)
plt.figure(figsize=(6,5))
RocCurveDisplay.from_predictions(y_test, test_proba)
plt.title("ROC Curve (TEST)")
plt.tight_layout()
plt.show()

plt.figure(figsize=(6,5))
PrecisionRecallDisplay.from_predictions(y_test, test_proba)
plt.title("Precision-Recall Curve (TEST)")
plt.tight_layout()
plt.show()

cm = confusion_matrix(y_test, test_pred)
plt.figure(figsize=(5.5,4.5))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", cbar=False)
plt.title(f"Confusion Matrix (TEST, thr={artifact['best_threshold']:.3f})")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.tight_layout()
plt.show()

# Calibration curve (확률 신뢰도)
prob_true, prob_pred = calibration_curve(y_test, test_proba, n_bins=10, strategy="quantile")
plt.figure(figsize=(6,5))
plt.plot(prob_pred, prob_true, marker="o", label="Model")
plt.plot([0,1],[0,1],"--", label="Perfect")
plt.title("Calibration Curve (TEST)")
plt.xlabel("Mean predicted probability")
plt.ylabel("Fraction of positives")
plt.legend()
plt.tight_layout()
plt.show()

# 확률 분포 (구매/비구매 분리 정도)
plt.figure(figsize=(7,4.5))
sns.kdeplot(test_proba[y_test==0], label="y=0", fill=True, alpha=0.35)
sns.kdeplot(test_proba[y_test==1], label="y=1", fill=True, alpha=0.35)
plt.title("Predicted Probability Distribution (TEST)")
plt.xlabel("Predicted probability")
plt.legend()
plt.tight_layout()
plt.show()

# %%
# pip install pandas numpy scikit-learn imbalanced-learn joblib

import numpy as np
import pandas as pd
import joblib

from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, RobustScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import (
    precision_recall_curve, f1_score,
    roc_auc_score, average_precision_score,
    confusion_matrix, classification_report
)

from imblearn.ensemble import BalancedRandomForestClassifier

# =========================
# Config
# =========================
TRAIN_PATH = "../../data/processed/train.csv"
TEST_PATH  = "../../data/processed/test.csv"
TARGET_COL = "Revenue"
MODEL_PATH = "brf_robust_onehot.joblib"
RANDOM_STATE = 42
N_SPLITS = 5

# =========================
# Load
# =========================
train_df = pd.read_csv(TRAIN_PATH)
test_df  = pd.read_csv(TEST_PATH)

if TARGET_COL not in train_df.columns:
    raise ValueError(f"'{TARGET_COL}' not in train.csv")

X_train = train_df.drop(columns=[TARGET_COL])
y_train = train_df[TARGET_COL].astype(int)

has_test_label = TARGET_COL in test_df.columns
X_test = test_df.drop(columns=[TARGET_COL]) if has_test_label else test_df.copy()
y_test = test_df[TARGET_COL].astype(int) if has_test_label else None

# =========================
# Column typing (자동 추정)
# =========================
num_cols = X_train.select_dtypes(include=["number"]).columns.tolist()
cat_cols = X_train.select_dtypes(include=["object", "bool", "category"]).columns.tolist()

preprocess = ColumnTransformer(
    transformers=[
        ("num", RobustScaler(), num_cols),
        ("cat", OneHotEncoder(handle_unknown="ignore"), cat_cols),
    ],
    remainder="drop",
)

# =========================
# Model: Balanced Random Forest
# =========================
brf = BalancedRandomForestClassifier(
    n_estimators=800,
    max_depth=None,
    min_samples_leaf=1,
    sampling_strategy="auto",   # 각 트리 학습 시 클래스 균형 샘플링
    replacement=False,
    n_jobs=-1,
    random_state=RANDOM_STATE
)

pipeline = Pipeline(steps=[
    ("preprocess", preprocess),
    ("model", brf),
])

# =========================
# 1) OOF로 threshold 튜닝 (추가 split 없음)
# =========================
skf = StratifiedKFold(n_splits=N_SPLITS, shuffle=True, random_state=RANDOM_STATE)
oof_proba = np.zeros(len(X_train), dtype=float)

for fold, (tr_idx, va_idx) in enumerate(skf.split(X_train, y_train), 1):
    X_tr, y_tr = X_train.iloc[tr_idx], y_train.iloc[tr_idx]
    X_va, y_va = X_train.iloc[va_idx], y_train.iloc[va_idx]

    pipeline.fit(X_tr, y_tr)
    oof_proba[va_idx] = pipeline.predict_proba(X_va)[:, 1]
    print(f"[Fold {fold}] done")

prec, rec, thr = precision_recall_curve(y_train, oof_proba)
f1s = 2 * (prec * rec) / (prec + rec + 1e-12)
best_idx = np.nanargmax(f1s)
best_thr = thr[best_idx - 1] if best_idx > 0 else 0.5

print("\n[OOF] Best threshold:", float(best_thr), "Best F1:", float(f1s[best_idx]))

# =========================
# 2) train 전체로 재학습
# =========================
pipeline.fit(X_train, y_train)

# =========================
# 3) test 평가(라벨 있으면)
# =========================
test_proba = pipeline.predict_proba(X_test)[:, 1]
test_pred = (test_proba >= best_thr).astype(int)

if has_test_label:
    print("\n=== TEST Metrics (BRF, OOF-threshold) ===")
    print("ROC-AUC :", roc_auc_score(y_test, test_proba))
    print("PR-AUC  :", average_precision_score(y_test, test_proba))
    print("F1      :", f1_score(y_test, test_pred))
    print("Confusion matrix:\n", confusion_matrix(y_test, test_pred))
    print("\nReport:\n", classification_report(y_test, test_pred, digits=4))
else:
    print("\n(test.csv에 Revenue가 없어 평가 대신 예측만 생성합니다.)")

# =========================
# 4) 모델 추출/저장 (pipeline + threshold)
# =========================
artifact = {
    "pipeline": pipeline,
    "best_threshold": float(best_thr),
    "num_cols": num_cols,
    "cat_cols": cat_cols
}
joblib.dump(artifact, MODEL_PATH)
print("\nSaved:", MODEL_PATH)
# Out:
# [Fold 1] done
# [Fold 2] done
# [Fold 3] done
# [Fold 4] done
# [Fold 5] done
#
# [OOF] Best threshold: 0.71375 Best F1: 0.6877300613491952
#
# === TEST Metrics (BRF, OOF-threshold) ===
# ROC-AUC : 0.9266940338254062
# PR-AUC  : 0.7221350170807316
# F1      : 0.6674907292954264
# Confusion matrix:
#  [[1927  157]
#  [ 112  270]]
#
# Report:
#                precision    recall  f1-score   support
#
#            0     0.9451    0.9247    0.9348      2084
#            1     0.6323    0.7068    0.6675       382
#
#     accuracy                         0.8909      2466
#    macro avg     0.7887    0.8157    0.8011      2466
# weighted avg     0.8966    0.8909    0.8934      2466
#
#
# Saved: brf_robust_onehot.joblib

# %%
# pip install pandas numpy scikit-learn imbalanced-learn joblib

import numpy as np
import pandas as pd
import joblib

from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, RobustScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import (
    precision_recall_curve, f1_score,
    roc_auc_score, average_precision_score,
    confusion_matrix, classification_report
)

from sklearn.linear_model import LogisticRegression
from imblearn.ensemble import EasyEnsembleClassifier

TRAIN_PATH = "../../data/processed/train.csv"
TEST_PATH  = "../../data/processed/test.csv"
TARGET_COL = "Revenue"
MODEL_PATH = "easyensemble_robust_onehot.joblib"
RANDOM_STATE = 42
N_SPLITS = 5

train_df = pd.read_csv(TRAIN_PATH)
test_df  = pd.read_csv(TEST_PATH)

X_train = train_df.drop(columns=[TARGET_COL])
y_train = train_df[TARGET_COL].astype(int)

has_test_label = TARGET_COL in test_df.columns
X_test = test_df.drop(columns=[TARGET_COL]) if has_test_label else test_df.copy()
y_test = test_df[TARGET_COL].astype(int) if has_test_label else None

num_cols = X_train.select_dtypes(include=["number"]).columns.tolist()
cat_cols = X_train.select_dtypes(include=["object", "bool", "category"]).columns.tolist()

preprocess = ColumnTransformer(
    transformers=[
        ("num", RobustScaler(), num_cols),
        ("cat", OneHotEncoder(handle_unknown="ignore"), cat_cols),
    ],
    remainder="drop",
)

# EasyEnsemble은 언더샘플링된 여러 서브셋을 만들고, 각 서브셋에 약한 분류기를 학습한 뒤 앙상블
base = LogisticRegression(max_iter=5000, solver="saga", class_weight=None, n_jobs=-1, random_state=RANDOM_STATE)

eec = EasyEnsembleClassifier(
    n_estimators=30,          # 서브셋 개수(늘리면 더 안정적/느려짐)
    estimator=base,
    random_state=RANDOM_STATE,
    n_jobs=-1
)

pipeline = Pipeline(steps=[
    ("preprocess", preprocess),
    ("model", eec),
])

# OOF threshold 튜닝
skf = StratifiedKFold(n_splits=N_SPLITS, shuffle=True, random_state=RANDOM_STATE)
oof_proba = np.zeros(len(X_train), dtype=float)

for fold, (tr_idx, va_idx) in enumerate(skf.split(X_train, y_train), 1):
    X_tr, y_tr = X_train.iloc[tr_idx], y_train.iloc[tr_idx]
    X_va, y_va = X_train.iloc[va_idx], y_train.iloc[va_idx]

    pipeline.fit(X_tr, y_tr)
    oof_proba[va_idx] = pipeline.predict_proba(X_va)[:, 1]
    print(f"[Fold {fold}] done")

prec, rec, thr = precision_recall_curve(y_train, oof_proba)
f1s = 2 * (prec * rec) / (prec + rec + 1e-12)
best_idx = np.nanargmax(f1s)
best_thr = thr[best_idx - 1] if best_idx > 0 else 0.5

print("\n[OOF] Best threshold:", float(best_thr), "Best F1:", float(f1s[best_idx]))

# train 전체 재학습
pipeline.fit(X_train, y_train)

# test 평가
test_proba = pipeline.predict_proba(X_test)[:, 1]
test_pred = (test_proba >= best_thr).astype(int)

if has_test_label:
    print("\n=== TEST Metrics (EasyEnsemble, OOF-threshold) ===")
    print("ROC-AUC :", roc_auc_score(y_test, test_proba))
    print("PR-AUC  :", average_precision_score(y_test, test_proba))
    print("F1      :", f1_score(y_test, test_pred))
    print("Confusion matrix:\n", confusion_matrix(y_test, test_pred))
    print("\nReport:\n", classification_report(y_test, test_pred, digits=4))

artifact = {"pipeline": pipeline, "best_threshold": float(best_thr), "num_cols": num_cols, "cat_cols": cat_cols}
joblib.dump(artifact, MODEL_PATH)
print("\nSaved:", MODEL_PATH)
# Out:
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [Fold 1] done
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [Fold 2] done
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [Fold 3] done
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [Fold 4] done
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [Fold 5] done
#
# [OOF] Best threshold: 0.5259804744275102 Best F1: 0.6616886846634938
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# === TEST Metrics (EasyEnsemble, OOF-threshold) ===
# ROC-AUC : 0.8887648099205113
# PR-AUC  : 0.6255419043848259
# F1      : 0.6239813736903376
# Confusion matrix:
#  [[1875  209]
#  [ 114  268]]
#
# Report:
#                precision    recall  f1-score   support
#
#            0     0.9427    0.8997    0.9207      2084
#            1     0.5618    0.7016    0.6240       382
#
#     accuracy                         0.8690      2466
#    macro avg     0.7523    0.8006    0.7723      2466
# weighted avg     0.8837    0.8690    0.8747      2466
#
#
# Saved: easyensemble_robust_onehot.joblib

# %%
import pandas as pd

train_df = pd.read_csv("../../data/processed/train.csv")
test_df  = pd.read_csv("../../data/processed/test.csv")

for name, df in [("train", train_df), ("test", test_df)]:
    if "Revenue" in df.columns:
        vc = df["Revenue"].astype(int).value_counts().sort_index()
        pos = int(vc.get(1, 0)); neg = int(vc.get(0, 0))
        print(f"{name}: pos={pos}, neg={neg}, pos_rate={pos/(pos+neg):.4f}")
# Out:
# train: pos=1526, neg=8338, pos_rate=0.1547
# test: pos=382, neg=2084, pos_rate=0.1549

# %%
# pip install pandas numpy scikit-learn imbalanced-learn joblib

import numpy as np
import pandas as pd

from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, RobustScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import StratifiedKFold

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
from sklearn.metrics import (
    precision_recall_curve, f1_score,
    roc_auc_score, average_precision_score,
    confusion_matrix, classification_report
)

from imblearn.ensemble import BalancedRandomForestClassifier, EasyEnsembleClassifier

TRAIN_PATH = "../../data/processed/train.csv"
TEST_PATH  = "../../data/processed/test.csv"
TARGET_COL = "Revenue"
RANDOM_STATE = 42
N_SPLITS = 5

train_df = pd.read_csv(TRAIN_PATH)
test_df  = pd.read_csv(TEST_PATH)

X_train = train_df.drop(columns=[TARGET_COL])
y_train = train_df[TARGET_COL].astype(int)

X_test = test_df.drop(columns=[TARGET_COL])
y_test = test_df[TARGET_COL].astype(int)

# 자동 컬럼 타입
num_cols = X_train.select_dtypes(include=["number"]).columns.tolist()
cat_cols = X_train.select_dtypes(include=["object", "bool", "category"]).columns.tolist()

preprocess = ColumnTransformer(
    transformers=[
        ("num", RobustScaler(), num_cols),
        ("cat", OneHotEncoder(handle_unknown="ignore"), cat_cols),
    ],
    remainder="drop",
)

def oof_best_threshold(model_pipeline, X, y, n_splits=5, seed=42):
    """train만으로 OOF 확률 생성 -> F1 최대 threshold 반환"""
    skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=seed)
    oof = np.zeros(len(X), dtype=float)

    for tr_idx, va_idx in skf.split(X, y):
        model_pipeline.fit(X.iloc[tr_idx], y.iloc[tr_idx])
        oof[va_idx] = model_pipeline.predict_proba(X.iloc[va_idx])[:, 1]

    prec, rec, thr = precision_recall_curve(y, oof)
    f1s = 2 * (prec * rec) / (prec + rec + 1e-12)
    best_idx = np.nanargmax(f1s)
    best_thr = thr[best_idx - 1] if best_idx > 0 else 0.5
    return float(best_thr), float(f1s[best_idx])

def fit_eval(name, base_model):
    pipe = Pipeline([("preprocess", preprocess), ("model", base_model)])

    best_thr, best_oof_f1 = oof_best_threshold(pipe, X_train, y_train, n_splits=N_SPLITS, seed=RANDOM_STATE)

    # train 전체로 재학습
    pipe.fit(X_train, y_train)

    test_proba = pipe.predict_proba(X_test)[:, 1]
    test_pred = (test_proba >= best_thr).astype(int)

    out = {
        "name": name,
        "oof_best_f1": best_oof_f1,
        "best_thr": best_thr,
        "test_f1": float(f1_score(y_test, test_pred)),
        "test_roc_auc": float(roc_auc_score(y_test, test_proba)),
        "test_pr_auc": float(average_precision_score(y_test, test_proba)),
        "pipe": pipe
    }
    return out, test_pred, test_proba

models = [
    ("LR_balanced", LogisticRegression(max_iter=5000, solver="saga", class_weight="balanced", n_jobs=-1, random_state=RANDOM_STATE)),
    ("BalancedRF", BalancedRandomForestClassifier(n_estimators=800, n_jobs=-1, random_state=RANDOM_STATE)),
    ("EasyEnsemble", EasyEnsembleClassifier(
        n_estimators=30,
        estimator=LogisticRegression(max_iter=5000, solver="saga", n_jobs=-1, random_state=RANDOM_STATE),
        n_jobs=-1,
        random_state=RANDOM_STATE
    )),
    ("ExtraTrees_balanced", ExtraTreesClassifier(n_estimators=800, class_weight="balanced", n_jobs=-1, random_state=RANDOM_STATE)),
]

results = []
best = None

for name, m in models:
    res, test_pred, test_proba = fit_eval(name, m)
    results.append(res)
    print(f"\n[{name}] OOF_best_F1={res['oof_best_f1']:.4f}, best_thr={res['best_thr']:.4f} | "
          f"TEST F1={res['test_f1']:.4f}, PR-AUC={res['test_pr_auc']:.4f}, ROC-AUC={res['test_roc_auc']:.4f}")

    if best is None or res["test_f1"] > best["test_f1"]:
        best = res

print("\n=== BEST by TEST F1 ===")
print(best["name"], "TEST F1=", best["test_f1"], "best_thr=", best["best_thr"])

# 최종 상세 리포트(베스트 모델로)
best_pipe = best["pipe"]
best_thr  = best["best_thr"]
best_test_proba = best_pipe.predict_proba(X_test)[:, 1]
best_test_pred  = (best_test_proba >= best_thr).astype(int)

print("\nConfusion matrix:\n", confusion_matrix(y_test, best_test_pred))
print("\nReport:\n", classification_report(y_test, best_test_pred, digits=4))
# Out:
# [LR_balanced] OOF_best_F1=0.6560, best_thr=0.5258 | TEST F1=0.6263, PR-AUC=0.6250, ROC-AUC=0.8924
#
# [BalancedRF] OOF_best_F1=0.6879, best_thr=0.5975 | TEST F1=0.6619, PR-AUC=0.7271, ROC-AUC=0.9260
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [EasyEnsemble] OOF_best_F1=0.6617, best_thr=0.5260 | TEST F1=0.6240, PR-AUC=0.6255, ROC-AUC=0.8888
#
# [ExtraTrees_balanced] OOF_best_F1=0.6620, best_thr=0.2825 | TEST F1=0.6381, PR-AUC=0.6910, ROC-AUC=0.9086
#
# === BEST by TEST F1 ===
# BalancedRF TEST F1= 0.6618705035971223 best_thr= 0.5975
#
# Confusion matrix:
#  [[1908  176]
#  [ 106  276]]
#
# Report:
#                precision    recall  f1-score   support
#
#            0     0.9474    0.9155    0.9312      2084
#            1     0.6106    0.7225    0.6619       382
#
#     accuracy                         0.8856      2466
#    macro avg     0.7790    0.8190    0.7965      2466
# weighted avg     0.8952    0.8856    0.8895      2466

# %%
# pip install pandas numpy scikit-learn imbalanced-learn joblib

import numpy as np
import pandas as pd
import joblib

from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, RobustScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import (
    precision_recall_curve, f1_score,
    roc_auc_score, average_precision_score,
    confusion_matrix, classification_report
)

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import ExtraTreesClassifier
from imblearn.ensemble import BalancedRandomForestClassifier, EasyEnsembleClassifier
from imblearn.pipeline import Pipeline as ImbPipeline
from imblearn.over_sampling import RandomOverSampler

TRAIN_PATH = "../../data/processed/train.csv"
TEST_PATH  = "../../data/processed/test.csv"
TARGET_COL = "Revenue"
RANDOM_STATE = 42
N_SPLITS = 5

train_df = pd.read_csv(TRAIN_PATH)
test_df  = pd.read_csv(TEST_PATH)

X_train = train_df.drop(columns=[TARGET_COL])
y_train = train_df[TARGET_COL].astype(int)

X_test = test_df.drop(columns=[TARGET_COL])
y_test = test_df[TARGET_COL].astype(int)

# ---- 컬럼 자동 분리 (원하면 여기서 수동 지정 가능)
num_cols = X_train.select_dtypes(include=["number"]).columns.tolist()
cat_cols = X_train.select_dtypes(include=["object", "bool", "category"]).columns.tolist()

preprocess = ColumnTransformer(
    transformers=[
        ("num", RobustScaler(), num_cols),
        ("cat", OneHotEncoder(handle_unknown="ignore"), cat_cols),
    ],
    remainder="drop",
)

def oof_best_threshold(pipeline, X, y, n_splits=5, seed=42):
    """train에서만 OOF 확률 생성 -> F1 최대 threshold 반환"""
    skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=seed)
    oof = np.zeros(len(X), dtype=float)

    for tr_idx, va_idx in skf.split(X, y):
        pipeline.fit(X.iloc[tr_idx], y.iloc[tr_idx])
        oof[va_idx] = pipeline.predict_proba(X.iloc[va_idx])[:, 1]

    prec, rec, thr = precision_recall_curve(y, oof)
    f1s = 2 * (prec * rec) / (prec + rec + 1e-12)
    best_idx = int(np.nanargmax(f1s))
    best_thr = float(thr[best_idx - 1]) if best_idx > 0 else 0.5
    return best_thr, float(f1s[best_idx])

def fit_eval(name, pipe):
    # 1) OOF로 best threshold
    thr, oof_f1 = oof_best_threshold(pipe, X_train, y_train, n_splits=N_SPLITS, seed=RANDOM_STATE)

    # 2) train 전체로 재학습
    pipe.fit(X_train, y_train)

    # 3) test 평가
    proba = pipe.predict_proba(X_test)[:, 1]
    pred = (proba >= thr).astype(int)

    return {
        "name": name,
        "oof_best_f1": oof_f1,
        "best_thr": thr,
        "test_f1": float(f1_score(y_test, pred)),
        "test_pr_auc": float(average_precision_score(y_test, proba)),
        "test_roc_auc": float(roc_auc_score(y_test, proba)),
        "pipe": pipe,
        "test_pred": pred,
        "test_proba": proba
    }

# ---- 후보 모델들 (F1 잘 나오는 쪽 위주)
candidates = []

# 1) ExtraTrees (강추: tabular에서 F1 잘 나오기 쉬움)
et = ExtraTreesClassifier(
    n_estimators=1200,
    min_samples_leaf=2,
    class_weight="balanced",
    n_jobs=-1,
    random_state=RANDOM_STATE
)
candidates.append(("ExtraTrees_balanced",
                   Pipeline([("preprocess", preprocess), ("model", et)])))

# 2) Balanced Random Forest
brf = BalancedRandomForestClassifier(
    n_estimators=900,
    min_samples_leaf=1,
    n_jobs=-1,
    random_state=RANDOM_STATE
)
candidates.append(("BalancedRF",
                   Pipeline([("preprocess", preprocess), ("model", brf)])))

# 3) EasyEnsemble (양성이 적을 때 특히 안정적인 경우 많음)
base_lr = LogisticRegression(max_iter=5000, solver="saga", n_jobs=-1, random_state=RANDOM_STATE)
eec = EasyEnsembleClassifier(
    n_estimators=40,
    estimator=base_lr,
    n_jobs=-1,
    random_state=RANDOM_STATE
)
candidates.append(("EasyEnsemble",
                   Pipeline([("preprocess", preprocess), ("model", eec)])))

# 4) (옵션) RandomOverSampler + LR (가중치 대신 표본 보강)
ros_lr = LogisticRegression(max_iter=5000, solver="saga", n_jobs=-1, random_state=RANDOM_STATE)
candidates.append(("ROS+LR",
                   ImbPipeline([("preprocess", preprocess),
                               ("ros", RandomOverSampler(random_state=RANDOM_STATE)),
                               ("model", ros_lr)])))

# ---- 실행
results = []
best = None

for name, pipe in candidates:
    res = fit_eval(name, pipe)
    results.append(res)
    print(f"\n[{name}] OOF_best_F1={res['oof_best_f1']:.4f}, thr={res['best_thr']:.4f} | "
          f"TEST F1={res['test_f1']:.4f}, PR-AUC={res['test_pr_auc']:.4f}, ROC-AUC={res['test_roc_auc']:.4f}")

    if best is None or res["test_f1"] > best["test_f1"]:
        best = res

print("\n=== BEST (by TEST F1) ===")
print(best["name"], "TEST F1=", best["test_f1"], "thr=", best["best_thr"])

print("\nConfusion matrix:\n", confusion_matrix(y_test, best["test_pred"]))
print("\nReport:\n", classification_report(y_test, best["test_pred"], digits=4))

# ---- 저장(모델 추출)
artifact = {
    "pipeline": best["pipe"],
    "best_threshold": float(best["best_thr"]),
    "model_name": best["name"],
    "num_cols": num_cols,
    "cat_cols": cat_cols
}
joblib.dump(artifact, "best_f1_model.joblib")
print("\nSaved: best_f1_model.joblib")
# Out:
# [ExtraTrees_balanced] OOF_best_F1=0.6495, thr=0.4819 | TEST F1=0.6311, PR-AUC=0.6781, ROC-AUC=0.9061
#
# [BalancedRF] OOF_best_F1=0.6869, thr=0.6122 | TEST F1=0.6626, PR-AUC=0.7266, ROC-AUC=0.9260
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [EasyEnsemble] OOF_best_F1=0.6610, thr=0.5442 | TEST F1=0.6237, PR-AUC=0.6259, ROC-AUC=0.8889
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [ROS+LR] OOF_best_F1=0.6532, thr=0.5543 | TEST F1=0.6280, PR-AUC=0.6268, ROC-AUC=0.8951
#
# === BEST (by TEST F1) ===
# BalancedRF TEST F1= 0.662621359223301 thr= 0.6122222222222222
#
# Confusion matrix:
#  [[1915  169]
#  [ 109  273]]
#
# Report:
#                precision    recall  f1-score   support
#
#            0     0.9461    0.9189    0.9323      2084
#            1     0.6176    0.7147    0.6626       382
#
#     accuracy                         0.8873      2466
#    macro avg     0.7819    0.8168    0.7975      2466
# weighted avg     0.8953    0.8873    0.8905      2466
#
#
# Saved: best_f1_model.joblib

# %%
# pip install pandas numpy scikit-learn imbalanced-learn joblib

import numpy as np
import pandas as pd

from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, RobustScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import precision_recall_curve, f1_score, roc_auc_score, average_precision_score

from imblearn.ensemble import BalancedRandomForestClassifier

TRAIN_PATH = "../../data/processed/train.csv"
TEST_PATH  = "../../data/processed/test.csv"
TARGET_COL = "Revenue"
RANDOM_STATE = 42
N_SPLITS = 5

train_df = pd.read_csv(TRAIN_PATH)
test_df  = pd.read_csv(TEST_PATH)

X_train = train_df.drop(columns=[TARGET_COL])
y_train = train_df[TARGET_COL].astype(int)
X_test  = test_df.drop(columns=[TARGET_COL])
y_test  = test_df[TARGET_COL].astype(int)

# 자동 컬럼 타입
num_cols = X_train.select_dtypes(include=["number"]).columns.tolist()
cat_cols = X_train.select_dtypes(include=["object", "bool", "category"]).columns.tolist()

preprocess = ColumnTransformer(
    transformers=[
        ("num", RobustScaler(), num_cols),
        ("cat", OneHotEncoder(handle_unknown="ignore"), cat_cols),
    ],
    remainder="drop",
)

def oof_proba_for_pipe(pipe, X, y, n_splits=5, seed=42):
    skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=seed)
    oof = np.zeros(len(X), dtype=float)
    for tr_idx, va_idx in skf.split(X, y):
        pipe.fit(X.iloc[tr_idx], y.iloc[tr_idx])
        oof[va_idx] = pipe.predict_proba(X.iloc[va_idx])[:, 1]
    return oof

def best_f1_threshold(y_true, proba):
    prec, rec, thr = precision_recall_curve(y_true, proba)
    f1s = 2 * (prec * rec) / (prec + rec + 1e-12)
    best_idx = int(np.nanargmax(f1s))
    best_thr = float(thr[best_idx - 1]) if best_idx > 0 else 0.5
    return best_thr, float(f1s[best_idx])

# ---- 튜닝 그리드 (너무 크면 오래 걸리니 "F1 잘 움직이는 축"만 잡음)
grid = []
for max_depth in [None, 8, 12, 16]:
    for min_leaf in [1, 2, 4, 8]:
        for max_features in ["sqrt", 0.5, 0.8]:
            grid.append({
                "n_estimators": 1200,
                "max_depth": max_depth,
                "min_samples_leaf": min_leaf,
                "min_samples_split": 2,
                "max_features": max_features,
                "sampling_strategy": "auto",
                "replacement": False,
            })

best = None

for i, params in enumerate(grid, 1):
    brf = BalancedRandomForestClassifier(
        n_estimators=params["n_estimators"],
        max_depth=params["max_depth"],
        min_samples_leaf=params["min_samples_leaf"],
        min_samples_split=params["min_samples_split"],
        max_features=params["max_features"],
        sampling_strategy=params["sampling_strategy"],
        replacement=params["replacement"],
        n_jobs=-1,
        random_state=RANDOM_STATE
    )
    pipe = Pipeline([("preprocess", preprocess), ("model", brf)])

    oof = oof_proba_for_pipe(pipe, X_train, y_train, n_splits=N_SPLITS, seed=RANDOM_STATE)
    thr, oof_f1 = best_f1_threshold(y_train, oof)

    # train 전체 재학습 후 test 평가
    pipe.fit(X_train, y_train)
    test_proba = pipe.predict_proba(X_test)[:, 1]
    test_pred = (test_proba >= thr).astype(int)
    test_f1 = float(f1_score(y_test, test_pred))

    if best is None or test_f1 > best["test_f1"]:
        best = {
            "params": params,
            "thr": thr,
            "oof_f1": oof_f1,
            "test_f1": test_f1,
            "test_pr_auc": float(average_precision_score(y_test, test_proba)),
            "test_roc_auc": float(roc_auc_score(y_test, test_proba)),
        }

    print(f"[{i}/{len(grid)}] depth={params['max_depth']}, leaf={params['min_samples_leaf']}, "
          f"max_feat={params['max_features']} | OOF_F1={oof_f1:.4f} thr={thr:.3f} | TEST_F1={test_f1:.4f}")

print("\n=== BEST CONFIG (by TEST F1) ===")
print(best)
# Out:
# [1/48] depth=None, leaf=1, max_feat=sqrt | OOF_F1=0.6890 thr=0.708 | TEST_F1=0.6667
# [2/48] depth=None, leaf=1, max_feat=0.5 | OOF_F1=0.6898 thr=0.738 | TEST_F1=0.6650
# [3/48] depth=None, leaf=1, max_feat=0.8 | OOF_F1=0.6870 thr=0.733 | TEST_F1=0.6675
# [4/48] depth=None, leaf=2, max_feat=sqrt | OOF_F1=0.6883 thr=0.729 | TEST_F1=0.6641
# [5/48] depth=None, leaf=2, max_feat=0.5 | OOF_F1=0.6950 thr=0.740 | TEST_F1=0.6716
# [6/48] depth=None, leaf=2, max_feat=0.8 | OOF_F1=0.6924 thr=0.734 | TEST_F1=0.6667
# [7/48] depth=None, leaf=4, max_feat=sqrt | OOF_F1=0.6889 thr=0.731 | TEST_F1=0.6607
# [8/48] depth=None, leaf=4, max_feat=0.5 | OOF_F1=0.6972 thr=0.740 | TEST_F1=0.6708
# [9/48] depth=None, leaf=4, max_feat=0.8 | OOF_F1=0.6935 thr=0.755 | TEST_F1=0.6642
# [10/48] depth=None, leaf=8, max_feat=sqrt | OOF_F1=0.6871 thr=0.705 | TEST_F1=0.6625
# [11/48] depth=None, leaf=8, max_feat=0.5 | OOF_F1=0.6996 thr=0.741 | TEST_F1=0.6740
# [12/48] depth=None, leaf=8, max_feat=0.8 | OOF_F1=0.6946 thr=0.737 | TEST_F1=0.6691
# [13/48] depth=8, leaf=1, max_feat=sqrt | OOF_F1=0.6868 thr=0.705 | TEST_F1=0.6675
# [14/48] depth=8, leaf=1, max_feat=0.5 | OOF_F1=0.6962 thr=0.739 | TEST_F1=0.6700
# [15/48] depth=8, leaf=1, max_feat=0.8 | OOF_F1=0.6954 thr=0.753 | TEST_F1=0.6609
# [16/48] depth=8, leaf=2, max_feat=sqrt | OOF_F1=0.6876 thr=0.701 | TEST_F1=0.6642
# [17/48] depth=8, leaf=2, max_feat=0.5 | OOF_F1=0.6984 thr=0.744 | TEST_F1=0.6716
# [18/48] depth=8, leaf=2, max_feat=0.8 | OOF_F1=0.6980 thr=0.739 | TEST_F1=0.6642
# [19/48] depth=8, leaf=4, max_feat=sqrt | OOF_F1=0.6860 thr=0.648 | TEST_F1=0.6521
# [20/48] depth=8, leaf=4, max_feat=0.5 | OOF_F1=0.6978 thr=0.741 | TEST_F1=0.6708
# [21/48] depth=8, leaf=4, max_feat=0.8 | OOF_F1=0.6961 thr=0.762 | TEST_F1=0.6725
# [22/48] depth=8, leaf=8, max_feat=sqrt | OOF_F1=0.6825 thr=0.647 | TEST_F1=0.6475
# [23/48] depth=8, leaf=8, max_feat=0.5 | OOF_F1=0.6986 thr=0.737 | TEST_F1=0.6700
# [24/48] depth=8, leaf=8, max_feat=0.8 | OOF_F1=0.6958 thr=0.747 | TEST_F1=0.6724
# [25/48] depth=12, leaf=1, max_feat=sqrt | OOF_F1=0.6904 thr=0.692 | TEST_F1=0.6634
# [26/48] depth=12, leaf=1, max_feat=0.5 | OOF_F1=0.6917 thr=0.736 | TEST_F1=0.6691
# [27/48] depth=12, leaf=1, max_feat=0.8 | OOF_F1=0.6901 thr=0.720 | TEST_F1=0.6643
# [28/48] depth=12, leaf=2, max_feat=sqrt | OOF_F1=0.6904 thr=0.696 | TEST_F1=0.6642
# [29/48] depth=12, leaf=2, max_feat=0.5 | OOF_F1=0.6962 thr=0.735 | TEST_F1=0.6691
# [30/48] depth=12, leaf=2, max_feat=0.8 | OOF_F1=0.6924 thr=0.744 | TEST_F1=0.6642
# [31/48] depth=12, leaf=4, max_feat=sqrt | OOF_F1=0.6892 thr=0.720 | TEST_F1=0.6625
# [32/48] depth=12, leaf=4, max_feat=0.5 | OOF_F1=0.6973 thr=0.742 | TEST_F1=0.6724
# [33/48] depth=12, leaf=4, max_feat=0.8 | OOF_F1=0.6945 thr=0.746 | TEST_F1=0.6699
# [34/48] depth=12, leaf=8, max_feat=sqrt | OOF_F1=0.6863 thr=0.715 | TEST_F1=0.6658
# [35/48] depth=12, leaf=8, max_feat=0.5 | OOF_F1=0.6969 thr=0.781 | TEST_F1=0.6718
# [36/48] depth=12, leaf=8, max_feat=0.8 | OOF_F1=0.6942 thr=0.779 | TEST_F1=0.6675
# [37/48] depth=16, leaf=1, max_feat=sqrt | OOF_F1=0.6873 thr=0.715 | TEST_F1=0.6608
# [38/48] depth=16, leaf=1, max_feat=0.5 | OOF_F1=0.6906 thr=0.738 | TEST_F1=0.6642
# [39/48] depth=16, leaf=1, max_feat=0.8 | OOF_F1=0.6875 thr=0.720 | TEST_F1=0.6627
# [40/48] depth=16, leaf=2, max_feat=sqrt | OOF_F1=0.6897 thr=0.718 | TEST_F1=0.6617
# [41/48] depth=16, leaf=2, max_feat=0.5 | OOF_F1=0.6934 thr=0.726 | TEST_F1=0.6659
# [42/48] depth=16, leaf=2, max_feat=0.8 | OOF_F1=0.6919 thr=0.741 | TEST_F1=0.6658
# [43/48] depth=16, leaf=4, max_feat=sqrt | OOF_F1=0.6877 thr=0.734 | TEST_F1=0.6616
# [44/48] depth=16, leaf=4, max_feat=0.5 | OOF_F1=0.6970 thr=0.726 | TEST_F1=0.6659
# [45/48] depth=16, leaf=4, max_feat=0.8 | OOF_F1=0.6937 thr=0.754 | TEST_F1=0.6675
# [46/48] depth=16, leaf=8, max_feat=sqrt | OOF_F1=0.6866 thr=0.709 | TEST_F1=0.6592
# [47/48] depth=16, leaf=8, max_feat=0.5 | OOF_F1=0.6983 thr=0.739 | TEST_F1=0.6732
# [48/48] depth=16, leaf=8, max_feat=0.8 | OOF_F1=0.6950 thr=0.737 | TEST_F1=0.6699
#
# === BEST CONFIG (by TEST F1) ===
# {'params': {'n_estimators': 1200, 'max_depth': None, 'min_samples_leaf': 8, 'min_samples_split': 2, 'max_features': 0.5, 'sampling_strategy': 'auto', 'replacement': False}, 'thr': 0.7412374222999228, 'oof_f1': 0.6995734308343593, 'test_f1': 0.6740467404674046, 'test_pr_auc': 0.7415823565968093, 'test_roc_auc': 0.9319585271979982}

# %%
# pip install pandas numpy scikit-learn imbalanced-learn joblib

import numpy as np
import pandas as pd
import joblib

from pathlib import Path

from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, RobustScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import StratifiedKFold, RandomizedSearchCV
from sklearn.metrics import average_precision_score, roc_auc_score

from imblearn.ensemble import BalancedRandomForestClassifier

TRAIN_PATH = "../../data/processed/train.csv"
TEST_PATH  = "../../data/processed/test.csv"
TARGET_COL = "Revenue"
OUT_PATH   = "artifacts/best_pr_auc_balancedrf.joblib"
RANDOM_STATE = 42

train_df = pd.read_csv(TRAIN_PATH)
test_df  = pd.read_csv(TEST_PATH)

X_train = train_df.drop(columns=[TARGET_COL])
y_train = train_df[TARGET_COL].astype(int)
X_test  = test_df.drop(columns=[TARGET_COL])
y_test  = test_df[TARGET_COL].astype(int)

num_cols = X_train.select_dtypes(include=["number"]).columns.tolist()
cat_cols = X_train.select_dtypes(include=["object", "bool", "category"]).columns.tolist()

preprocess = ColumnTransformer(
    transformers=[
        ("num", RobustScaler(), num_cols),
        ("cat", OneHotEncoder(handle_unknown="ignore"), cat_cols),
    ],
    remainder="drop",
)

base = BalancedRandomForestClassifier(
    n_jobs=-1,
    random_state=RANDOM_STATE
)

pipe = Pipeline([
    ("preprocess", preprocess),
    ("model", base),
])

# PR-AUC 최적화용 탐색 공간 (너무 크게 잡지 말고, 영향 큰 축 위주)
param_dist = {
    "model__n_estimators": [300, 500, 800, 1200],
    "model__max_depth": [None, 8, 12, 16, 20],
    "model__min_samples_leaf": [1, 2, 4, 8, 12],
    "model__min_samples_split": [2, 5, 10],
    "model__max_features": ["sqrt", 0.3, 0.5, 0.8],
    "model__sampling_strategy": ["auto", 0.5, 0.7, 1.0],
    "model__replacement": [False, True],
}

cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=RANDOM_STATE)

search = RandomizedSearchCV(
    estimator=pipe,
    param_distributions=param_dist,
    n_iter=40,  # 시간 여유 있으면 80~120까지 올리면 더 좋아짐
    scoring="average_precision",  # PR-AUC
    cv=cv,
    refit=True,  # best 모델로 train 전체 재학습
    n_jobs=-1,
    random_state=RANDOM_STATE,
    verbose=2,
)

search.fit(X_train, y_train)

best_model = search.best_estimator_
print("\nBest CV PR-AUC:", search.best_score_)
print("Best params:", search.best_params_)

# test 평가(참고용)
test_proba = best_model.predict_proba(X_test)[:, 1]
print("\nTEST PR-AUC :", average_precision_score(y_test, test_proba))
print("TEST ROC-AUC:", roc_auc_score(y_test, test_proba))

# 저장 (압축 권장)
artifact = {
    "pipeline": best_model,
    "best_params": search.best_params_,
    "cv_best_pr_auc": float(search.best_score_),
    "num_cols": num_cols,
    "cat_cols": cat_cols,
    "target_col": TARGET_COL,
}
Path(OUT_PATH).parent.mkdir(parents=True, exist_ok=True)
joblib.dump(artifact, OUT_PATH, compress=("xz", 3))
print("\nSaved:", OUT_PATH)
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# [CV] END model__max_depth=16, model__max_features=0.8, model__min_samples_leaf=1, model__min_samples_split=10, model__n_estimators=300, model__replacement=True, model__sampling_strategy=0.7; total time=   6.3s
# [CV] END model__max_depth=16, model__max_features=0.8, model__min_samples_leaf=1, model__min_samples_split=10, model__n_estimators=300, model__replacement=True, model__sampling_strategy=0.7; total time=   6.3s
# [CV] END model__max_depth=16, model__max_features=0.8, model__min_samples_leaf=1, model__min_samples_split=10, model__n_estimators=300, model__replacement=True, model__sampling_strategy=0.7; total time=   6.4s
# [CV] END model__max_depth=16, model__max_features=0.8, model__min_samples_leaf=1, model__min_samples_split=10, model__n_estimators=300, model__replacement=True, model__sampling_strategy=0.7; total time=   6.4s
# [CV] END model__max_depth=16, model__max_features=0.8, model__min_samples_leaf=1, model__min_samples_split=10, model__n_estimators=300, model__replacement=True, model__sampling_strategy=0.7; total time=   6.5s
# [CV] END model__max_depth=None, model__max_features=0.3, model__min_samples_leaf=8, model__min_samples_split=10, model__n_estimators=1200, model__replacement=True, model__sampling_strategy=auto; total time=  11.6s
# [CV] END model__max_depth=None, model__max_features=0.3, model__min_samples_leaf=8, model__min_samples_split=10, model__n_estimators=1200, model__replacement=True, model__sampling_strategy=auto; total time=  12.3s
# [CV] END model__max_depth=None, model__max_features=0.3, model__min_samples_leaf=8, model__min_samples_split=10, model__n_estimators=1200, model__replacement=True, model__sampling_strategy=auto; total time=  12.3s
# [CV] END model__max_depth=12, model__max_features=0.5, model__min_samples_leaf=12, model__min_samples_split=2, model__n_estimators=300, model__replacement=True, model__sampling_strategy=1.0; total time=   3.6s
# [CV] END model__max_depth=12, model__max_features=0.8, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=500, model__replacement=True, model__sampling_strategy=0.7; total time=  10.2s
# [CV] END model__max_depth=12, model__max_features=0.8, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=500, model__replacement=True, model__sampling_strategy=0.7; total time=  10.4s
# [CV] END model__max_depth=12, model__max_features=0.8, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=500, model__replacement=True, model__sampling_strategy=0.7; total time=  10.5s
# [CV] END model__max_depth=None, model__max_features=0.3, model__min_samples_leaf=8, model__min_samples_split=10, model__n_estimators=1200, model__replacement=True, model__sampling_strategy=auto; total time=  12.2s
# [CV] END model__max_depth=None, model__max_features=0.3, model__min_samples_leaf=8, model__min_samples_split=10, model__n_estimators=1200, model__replacement=True, model__sampling_strategy=auto; total time=  12.2s
# [CV] END model__max_depth=12, model__max_features=0.5, model__min_samples_leaf=12, model__min_samples_split=2, model__n_estimators=300, model__replacement=True, model__sampling_strategy=1.0; total time=   3.2s
# [CV] END model__max_depth=12, model__max_features=0.5, model__min_samples_leaf=12, model__min_samples_split=2, model__n_estimators=300, model__replacement=True, model__sampling_strategy=1.0; total time=   3.1s
# [CV] END model__max_depth=12, model__max_features=0.5, model__min_samples_leaf=12, model__min_samples_split=2, model__n_estimators=300, model__replacement=True, model__sampling_strategy=1.0; total time=   3.0s
# [CV] END model__max_depth=12, model__max_features=0.5, model__min_samples_leaf=12, model__min_samples_split=2, model__n_estimators=300, model__replacement=True, model__sampling_strategy=1.0; total time=   3.2s
# [CV] END model__max_depth=12, model__max_features=0.8, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=500, model__replacement=True, model__sampling_strategy=0.7; total time=   9.8s
# [CV] END model__max_depth=12, model__max_features=0.8, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=500, model__replacement=True, model__sampling_strategy=0.7; total time=   9.6s
# [CV] END model__max_depth=12, model__max_features=0.8, model__min_samples_leaf=12, model__min_samples_split=10, model__n_estimators=300, model__replacement=True, model__sampling_strategy=0.7; total time=   4.4s
# [CV] END model__max_depth=12, model__max_features=0.8, model__min_samples_leaf=12, model__min_samples_split=10, model__n_estimators=300, model__replacement=True, model__sampling_strategy=0.7; total time=   4.5s
# [CV] END model__max_depth=12, model__max_features=0.8, model__min_samples_leaf=12, model__min_samples_split=10, model__n_estimators=300, model__replacement=True, model__sampling_strategy=0.7; total time=   4.1s
# [CV] END model__max_depth=12, model__max_features=0.8, model__min_samples_leaf=12, model__min_samples_split=10, model__n_estimators=300, model__replacement=True, model__sampling_strategy=0.7; total time=   3.9s
# [CV] END model__max_depth=12, model__max_features=0.8, model__min_samples_leaf=12, model__min_samples_split=10, model__n_estimators=300, model__replacement=True, model__sampling_strategy=0.7; total time=   3.9s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=12, model__min_samples_split=10, model__n_estimators=800, model__replacement=False, model__sampling_strategy=0.7; total time=   6.5s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=12, model__min_samples_split=10, model__n_estimators=800, model__replacement=False, model__sampling_strategy=0.7; total time=   6.6s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=12, model__min_samples_split=10, model__n_estimators=800, model__replacement=False, model__sampling_strategy=0.7; total time=   6.6s
# [CV] END model__max_depth=16, model__max_features=0.3, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=1200, model__replacement=False, model__sampling_strategy=0.5; total time=  15.7s
# [CV] END model__max_depth=12, model__max_features=0.3, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=500, model__replacement=False, model__sampling_strategy=0.7; total time=   5.8s
# [CV] END model__max_depth=16, model__max_features=0.3, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=1200, model__replacement=False, model__sampling_strategy=0.5; total time=  15.3s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=12, model__min_samples_split=10, model__n_estimators=800, model__replacement=False, model__sampling_strategy=0.7; total time=   7.0s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=12, model__min_samples_split=10, model__n_estimators=800, model__replacement=False, model__sampling_strategy=0.7; total time=   7.0s
# [CV] END model__max_depth=16, model__max_features=0.3, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=1200, model__replacement=False, model__sampling_strategy=0.5; total time=  15.7s
# [CV] END model__max_depth=16, model__max_features=0.3, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=1200, model__replacement=False, model__sampling_strategy=0.5; total time=  15.3s
# [CV] END model__max_depth=16, model__max_features=0.3, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=1200, model__replacement=False, model__sampling_strategy=0.5; total time=  15.5s
# [CV] END model__max_depth=12, model__max_features=0.3, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=500, model__replacement=False, model__sampling_strategy=0.7; total time=   5.3s
# [CV] END model__max_depth=12, model__max_features=0.3, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=500, model__replacement=False, model__sampling_strategy=0.7; total time=   5.3s
# [CV] END model__max_depth=12, model__max_features=0.3, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=500, model__replacement=False, model__sampling_strategy=0.7; total time=   5.2s
# [CV] END model__max_depth=12, model__max_features=0.3, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=500, model__replacement=False, model__sampling_strategy=0.7; total time=   5.5s
# [CV] END model__max_depth=20, model__max_features=0.3, model__min_samples_leaf=2, model__min_samples_split=10, model__n_estimators=300, model__replacement=False, model__sampling_strategy=0.7; total time=   3.8s
# [CV] END model__max_depth=20, model__max_features=0.3, model__min_samples_leaf=2, model__min_samples_split=10, model__n_estimators=300, model__replacement=False, model__sampling_strategy=0.7; total time=   3.9s
# [CV] END model__max_depth=12, model__max_features=0.8, model__min_samples_leaf=8, model__min_samples_split=2, model__n_estimators=500, model__replacement=False, model__sampling_strategy=0.7; total time=   9.1s
# [CV] END model__max_depth=20, model__max_features=0.3, model__min_samples_leaf=2, model__min_samples_split=10, model__n_estimators=300, model__replacement=False, model__sampling_strategy=0.7; total time=   4.0s
# [CV] END model__max_depth=12, model__max_features=0.8, model__min_samples_leaf=8, model__min_samples_split=2, model__n_estimators=500, model__replacement=False, model__sampling_strategy=0.7; total time=   9.3s
# [CV] END model__max_depth=12, model__max_features=0.8, model__min_samples_leaf=8, model__min_samples_split=2, model__n_estimators=500, model__replacement=False, model__sampling_strategy=0.7; total time=   9.1s
# [CV] END model__max_depth=12, model__max_features=0.8, model__min_samples_leaf=8, model__min_samples_split=2, model__n_estimators=500, model__replacement=False, model__sampling_strategy=0.7; total time=   9.2s
# [CV] END model__max_depth=20, model__max_features=0.3, model__min_samples_leaf=2, model__min_samples_split=10, model__n_estimators=300, model__replacement=False, model__sampling_strategy=0.7; total time=   3.1s
# [CV] END model__max_depth=20, model__max_features=0.3, model__min_samples_leaf=2, model__min_samples_split=10, model__n_estimators=300, model__replacement=False, model__sampling_strategy=0.7; total time=   2.8s
# [CV] END model__max_depth=12, model__max_features=0.8, model__min_samples_leaf=8, model__min_samples_split=2, model__n_estimators=500, model__replacement=False, model__sampling_strategy=0.7; total time=   8.5s
# [CV] END model__max_depth=None, model__max_features=0.3, model__min_samples_leaf=8, model__min_samples_split=2, model__n_estimators=300, model__replacement=False, model__sampling_strategy=0.5; total time=   3.9s
# [CV] END model__max_depth=None, model__max_features=0.3, model__min_samples_leaf=8, model__min_samples_split=2, model__n_estimators=300, model__replacement=False, model__sampling_strategy=0.5; total time=   4.1s
# [CV] END model__max_depth=None, model__max_features=0.3, model__min_samples_leaf=8, model__min_samples_split=2, model__n_estimators=300, model__replacement=False, model__sampling_strategy=0.5; total time=   4.1s
# [CV] END model__max_depth=None, model__max_features=0.3, model__min_samples_leaf=8, model__min_samples_split=2, model__n_estimators=300, model__replacement=False, model__sampling_strategy=0.5; total time=   4.2s
# [CV] END model__max_depth=None, model__max_features=0.3, model__min_samples_leaf=8, model__min_samples_split=2, model__n_estimators=300, model__replacement=False, model__sampling_strategy=0.5; total time=   4.0s
# [CV] END model__max_depth=16, model__max_features=0.5, model__min_samples_leaf=4, model__min_samples_split=5, model__n_estimators=300, model__replacement=True, model__sampling_strategy=0.5; total time=   5.6s
# [CV] END model__max_depth=16, model__max_features=0.5, model__min_samples_leaf=4, model__min_samples_split=5, model__n_estimators=300, model__replacement=True, model__sampling_strategy=0.5; total time=   5.6s
# [CV] END model__max_depth=16, model__max_features=0.5, model__min_samples_leaf=4, model__min_samples_split=5, model__n_estimators=300, model__replacement=True, model__sampling_strategy=0.5; total time=   5.7s
# [CV] END model__max_depth=16, model__max_features=0.5, model__min_samples_leaf=4, model__min_samples_split=5, model__n_estimators=300, model__replacement=True, model__sampling_strategy=0.5; total time=   5.6s
# [CV] END model__max_depth=None, model__max_features=0.8, model__min_samples_leaf=4, model__min_samples_split=5, model__n_estimators=800, model__replacement=True, model__sampling_strategy=0.5; total time=  18.7s
# [CV] END model__max_depth=None, model__max_features=0.8, model__min_samples_leaf=4, model__min_samples_split=5, model__n_estimators=800, model__replacement=True, model__sampling_strategy=0.5; total time=  18.6s
# [CV] END model__max_depth=None, model__max_features=0.8, model__min_samples_leaf=4, model__min_samples_split=5, model__n_estimators=800, model__replacement=True, model__sampling_strategy=0.5; total time=  18.6s
# [CV] END model__max_depth=None, model__max_features=0.8, model__min_samples_leaf=4, model__min_samples_split=5, model__n_estimators=800, model__replacement=True, model__sampling_strategy=0.5; total time=  18.5s
# [CV] END model__max_depth=8, model__max_features=0.3, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=300, model__replacement=False, model__sampling_strategy=0.5; total time=   3.5s
# [CV] END model__max_depth=None, model__max_features=0.8, model__min_samples_leaf=4, model__min_samples_split=5, model__n_estimators=800, model__replacement=True, model__sampling_strategy=0.5; total time=  18.7s
# [CV] END model__max_depth=16, model__max_features=0.5, model__min_samples_leaf=4, model__min_samples_split=5, model__n_estimators=300, model__replacement=True, model__sampling_strategy=0.5; total time=   4.9s
# [CV] END model__max_depth=8, model__max_features=0.3, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=300, model__replacement=False, model__sampling_strategy=0.5; total time=   2.7s
# [CV] END model__max_depth=8, model__max_features=0.3, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=300, model__replacement=False, model__sampling_strategy=0.5; total time=   2.7s
# [CV] END model__max_depth=8, model__max_features=0.3, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=300, model__replacement=False, model__sampling_strategy=0.5; total time=   2.6s
# [CV] END model__max_depth=8, model__max_features=0.3, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=300, model__replacement=False, model__sampling_strategy=0.5; total time=   2.7s
# [CV] END model__max_depth=12, model__max_features=0.5, model__min_samples_leaf=4, model__min_samples_split=5, model__n_estimators=1200, model__replacement=False, model__sampling_strategy=1.0; total time=  17.3s
# [CV] END model__max_depth=12, model__max_features=0.5, model__min_samples_leaf=4, model__min_samples_split=5, model__n_estimators=1200, model__replacement=False, model__sampling_strategy=1.0; total time=  17.5s
# [CV] END model__max_depth=12, model__max_features=0.5, model__min_samples_leaf=4, model__min_samples_split=5, model__n_estimators=1200, model__replacement=False, model__sampling_strategy=1.0; total time=  17.1s
# [CV] END model__max_depth=12, model__max_features=0.8, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=1200, model__replacement=True, model__sampling_strategy=1.0; total time=  21.4s
# [CV] END model__max_depth=12, model__max_features=0.8, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=1200, model__replacement=True, model__sampling_strategy=1.0; total time=  21.4s
# [CV] END model__max_depth=12, model__max_features=0.8, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=1200, model__replacement=True, model__sampling_strategy=1.0; total time=  21.5s
# [CV] END model__max_depth=12, model__max_features=0.8, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=1200, model__replacement=True, model__sampling_strategy=1.0; total time=  21.6s
# [CV] END model__max_depth=12, model__max_features=0.8, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=1200, model__replacement=True, model__sampling_strategy=1.0; total time=  21.4s
# [CV] END model__max_depth=16, model__max_features=0.3, model__min_samples_leaf=2, model__min_samples_split=10, model__n_estimators=800, model__replacement=True, model__sampling_strategy=auto; total time=   7.9s
# [CV] END model__max_depth=None, model__max_features=0.5, model__min_samples_leaf=4, model__min_samples_split=5, model__n_estimators=300, model__replacement=False, model__sampling_strategy=auto; total time=   4.7s
# [CV] END model__max_depth=16, model__max_features=0.3, model__min_samples_leaf=2, model__min_samples_split=10, model__n_estimators=800, model__replacement=True, model__sampling_strategy=auto; total time=   8.3s
# [CV] END model__max_depth=16, model__max_features=0.3, model__min_samples_leaf=2, model__min_samples_split=10, model__n_estimators=800, model__replacement=True, model__sampling_strategy=auto; total time=   8.6s
# [CV] END model__max_depth=16, model__max_features=0.3, model__min_samples_leaf=2, model__min_samples_split=10, model__n_estimators=800, model__replacement=True, model__sampling_strategy=auto; total time=   9.2s
# [CV] END model__max_depth=16, model__max_features=0.3, model__min_samples_leaf=2, model__min_samples_split=10, model__n_estimators=800, model__replacement=True, model__sampling_strategy=auto; total time=   8.5s
# [CV] END model__max_depth=None, model__max_features=0.5, model__min_samples_leaf=4, model__min_samples_split=5, model__n_estimators=300, model__replacement=False, model__sampling_strategy=auto; total time=   4.3s
# [CV] END model__max_depth=None, model__max_features=0.5, model__min_samples_leaf=4, model__min_samples_split=5, model__n_estimators=300, model__replacement=False, model__sampling_strategy=auto; total time=   4.2s
# [CV] END model__max_depth=None, model__max_features=0.5, model__min_samples_leaf=4, model__min_samples_split=5, model__n_estimators=300, model__replacement=False, model__sampling_strategy=auto; total time=   3.9s
# [CV] END model__max_depth=None, model__max_features=0.5, model__min_samples_leaf=4, model__min_samples_split=5, model__n_estimators=300, model__replacement=False, model__sampling_strategy=auto; total time=   4.3s
# [CV] END model__max_depth=12, model__max_features=0.5, model__min_samples_leaf=4, model__min_samples_split=5, model__n_estimators=1200, model__replacement=False, model__sampling_strategy=1.0; total time=  15.6s
# [CV] END model__max_depth=12, model__max_features=0.3, model__min_samples_leaf=4, model__min_samples_split=5, model__n_estimators=500, model__replacement=False, model__sampling_strategy=1.0; total time=   5.1s
# [CV] END model__max_depth=12, model__max_features=0.5, model__min_samples_leaf=4, model__min_samples_split=5, model__n_estimators=1200, model__replacement=False, model__sampling_strategy=1.0; total time=  16.6s
# [CV] END model__max_depth=12, model__max_features=0.3, model__min_samples_leaf=4, model__min_samples_split=5, model__n_estimators=500, model__replacement=False, model__sampling_strategy=1.0; total time=   5.0s
# [CV] END model__max_depth=12, model__max_features=0.3, model__min_samples_leaf=4, model__min_samples_split=5, model__n_estimators=500, model__replacement=False, model__sampling_strategy=1.0; total time=   4.8s
# [CV] END model__max_depth=12, model__max_features=0.3, model__min_samples_leaf=4, model__min_samples_split=5, model__n_estimators=500, model__replacement=False, model__sampling_strategy=1.0; total time=   5.0s
# [CV] END model__max_depth=12, model__max_features=0.3, model__min_samples_leaf=4, model__min_samples_split=5, model__n_estimators=500, model__replacement=False, model__sampling_strategy=1.0; total time=   4.3s
# [CV] END model__max_depth=16, model__max_features=0.3, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=1200, model__replacement=True, model__sampling_strategy=auto; total time=  14.1s
# [CV] END model__max_depth=16, model__max_features=0.3, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=1200, model__replacement=True, model__sampling_strategy=auto; total time=  14.2s
# [CV] END model__max_depth=16, model__max_features=0.3, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=1200, model__replacement=True, model__sampling_strategy=auto; total time=  14.0s
# [CV] END model__max_depth=8, model__max_features=0.8, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=1200, model__replacement=False, model__sampling_strategy=0.5; total time=  25.2s
# [CV] END model__max_depth=8, model__max_features=0.8, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=1200, model__replacement=False, model__sampling_strategy=0.5; total time=  25.1s
# [CV] END model__max_depth=8, model__max_features=0.8, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=1200, model__replacement=False, model__sampling_strategy=0.5; total time=  25.1s
# [CV] END model__max_depth=8, model__max_features=0.8, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=1200, model__replacement=False, model__sampling_strategy=0.5; total time=  25.6s
# [CV] END model__max_depth=8, model__max_features=0.8, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=1200, model__replacement=False, model__sampling_strategy=0.5; total time=  25.3s
# [CV] END model__max_depth=16, model__max_features=0.3, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=1200, model__replacement=True, model__sampling_strategy=auto; total time=  12.8s
# [CV] END model__max_depth=16, model__max_features=0.3, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=1200, model__replacement=True, model__sampling_strategy=auto; total time=  13.4s
# [CV] END model__max_depth=20, model__max_features=0.5, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=1200, model__replacement=False, model__sampling_strategy=0.7; total time=  24.9s
# [CV] END model__max_depth=20, model__max_features=0.5, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=1200, model__replacement=False, model__sampling_strategy=0.7; total time=  24.0s
# [CV] END model__max_depth=20, model__max_features=0.5, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=1200, model__replacement=False, model__sampling_strategy=0.7; total time=  24.3s
# [CV] END model__max_depth=20, model__max_features=0.5, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=1200, model__replacement=False, model__sampling_strategy=0.7; total time=  24.8s
# [CV] END model__max_depth=20, model__max_features=0.5, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=1200, model__replacement=False, model__sampling_strategy=0.7; total time=  25.0s
# [CV] END model__max_depth=20, model__max_features=0.8, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=1200, model__replacement=False, model__sampling_strategy=0.7; total time=  30.6s
# [CV] END model__max_depth=20, model__max_features=0.8, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=1200, model__replacement=False, model__sampling_strategy=0.7; total time=  31.3s
# [CV] END model__max_depth=20, model__max_features=0.8, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=1200, model__replacement=False, model__sampling_strategy=0.7; total time=  32.7s
# [CV] END model__max_depth=8, model__max_features=0.3, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=1200, model__replacement=True, model__sampling_strategy=0.7; total time=  15.8s
# [CV] END model__max_depth=8, model__max_features=0.3, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=1200, model__replacement=True, model__sampling_strategy=0.7; total time=  16.8s
# [CV] END model__max_depth=8, model__max_features=0.3, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=1200, model__replacement=True, model__sampling_strategy=0.7; total time=  16.8s
# [CV] END model__max_depth=20, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=10, model__n_estimators=500, model__replacement=False, model__sampling_strategy=0.5; total time=   8.9s
# [CV] END model__max_depth=20, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=10, model__n_estimators=500, model__replacement=False, model__sampling_strategy=0.5; total time=   8.8s
# [CV] END model__max_depth=20, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=10, model__n_estimators=500, model__replacement=False, model__sampling_strategy=0.5; total time=   7.4s
# [CV] END model__max_depth=8, model__max_features=0.3, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=1200, model__replacement=True, model__sampling_strategy=0.7; total time=  17.9s
# [CV] END model__max_depth=20, model__max_features=0.8, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=1200, model__replacement=False, model__sampling_strategy=0.7; total time=  33.2s
# [CV] END model__max_depth=20, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=10, model__n_estimators=500, model__replacement=False, model__sampling_strategy=0.5; total time=   7.4s
# [CV] END model__max_depth=8, model__max_features=0.3, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=1200, model__replacement=True, model__sampling_strategy=0.7; total time=  16.8s
# [CV] END model__max_depth=20, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=10, model__n_estimators=500, model__replacement=False, model__sampling_strategy=0.5; total time=   6.0s
# [CV] END model__max_depth=20, model__max_features=0.8, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=1200, model__replacement=False, model__sampling_strategy=0.7; total time=  30.1s
# [CV] END model__max_depth=8, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=1200, model__replacement=True, model__sampling_strategy=1.0; total time=  12.9s
# [CV] END model__max_depth=8, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=1200, model__replacement=True, model__sampling_strategy=1.0; total time=  12.1s
# [CV] END model__max_depth=8, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=1200, model__replacement=True, model__sampling_strategy=1.0; total time=  11.9s
# [CV] END model__max_depth=8, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=1200, model__replacement=True, model__sampling_strategy=1.0; total time=  12.6s
# [CV] END model__max_depth=8, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=1200, model__replacement=True, model__sampling_strategy=1.0; total time=  12.2s
# [CV] END model__max_depth=8, model__max_features=0.3, model__min_samples_leaf=8, model__min_samples_split=5, model__n_estimators=1200, model__replacement=False, model__sampling_strategy=1.0; total time=  15.0s
# [CV] END model__max_depth=8, model__max_features=0.3, model__min_samples_leaf=8, model__min_samples_split=5, model__n_estimators=1200, model__replacement=False, model__sampling_strategy=1.0; total time=  15.7s
# [CV] END model__max_depth=8, model__max_features=0.3, model__min_samples_leaf=8, model__min_samples_split=5, model__n_estimators=1200, model__replacement=False, model__sampling_strategy=1.0; total time=  17.0s
# [CV] END model__max_depth=20, model__max_features=0.8, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=500, model__replacement=True, model__sampling_strategy=1.0; total time=  13.0s
# [CV] END model__max_depth=20, model__max_features=0.8, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=500, model__replacement=True, model__sampling_strategy=1.0; total time=  13.3s
# [CV] END model__max_depth=20, model__max_features=0.8, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=500, model__replacement=True, model__sampling_strategy=1.0; total time=  13.2s
# [CV] END model__max_depth=8, model__max_features=0.3, model__min_samples_leaf=8, model__min_samples_split=5, model__n_estimators=1200, model__replacement=False, model__sampling_strategy=1.0; total time=  15.2s
# [CV] END model__max_depth=8, model__max_features=0.3, model__min_samples_leaf=8, model__min_samples_split=5, model__n_estimators=1200, model__replacement=False, model__sampling_strategy=1.0; total time=  15.3s
# [CV] END model__max_depth=20, model__max_features=0.8, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=500, model__replacement=True, model__sampling_strategy=1.0; total time=  13.4s
# [CV] END model__max_depth=20, model__max_features=0.8, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=500, model__replacement=True, model__sampling_strategy=1.0; total time=  13.4s
# [CV] END model__max_depth=8, model__max_features=0.3, model__min_samples_leaf=8, model__min_samples_split=5, model__n_estimators=500, model__replacement=True, model__sampling_strategy=0.7; total time=   8.5s
# [CV] END model__max_depth=8, model__max_features=0.3, model__min_samples_leaf=8, model__min_samples_split=5, model__n_estimators=500, model__replacement=True, model__sampling_strategy=0.7; total time=   9.0s
# [CV] END model__max_depth=8, model__max_features=0.3, model__min_samples_leaf=8, model__min_samples_split=5, model__n_estimators=500, model__replacement=True, model__sampling_strategy=0.7; total time=   9.2s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=10, model__n_estimators=1200, model__replacement=True, model__sampling_strategy=0.5; total time=  20.8s
# [CV] END model__max_depth=8, model__max_features=0.3, model__min_samples_leaf=8, model__min_samples_split=5, model__n_estimators=500, model__replacement=True, model__sampling_strategy=0.7; total time=   8.2s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=10, model__n_estimators=1200, model__replacement=True, model__sampling_strategy=0.5; total time=  19.0s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=10, model__n_estimators=1200, model__replacement=True, model__sampling_strategy=0.5; total time=  18.9s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=10, model__n_estimators=1200, model__replacement=True, model__sampling_strategy=0.5; total time=  19.6s
# [CV] END model__max_depth=8, model__max_features=0.3, model__min_samples_leaf=8, model__min_samples_split=5, model__n_estimators=500, model__replacement=True, model__sampling_strategy=0.7; total time=   6.8s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=10, model__n_estimators=1200, model__replacement=True, model__sampling_strategy=0.5; total time=  19.0s
# [CV] END model__max_depth=12, model__max_features=0.3, model__min_samples_leaf=8, model__min_samples_split=5, model__n_estimators=800, model__replacement=False, model__sampling_strategy=0.7; total time=  13.3s
# [CV] END model__max_depth=12, model__max_features=0.3, model__min_samples_leaf=8, model__min_samples_split=5, model__n_estimators=800, model__replacement=False, model__sampling_strategy=0.7; total time=  13.1s
# [CV] END model__max_depth=12, model__max_features=0.3, model__min_samples_leaf=8, model__min_samples_split=5, model__n_estimators=800, model__replacement=False, model__sampling_strategy=0.7; total time=  13.9s
# [CV] END model__max_depth=8, model__max_features=0.5, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=1200, model__replacement=True, model__sampling_strategy=0.5; total time=  29.3s
# [CV] END model__max_depth=8, model__max_features=0.5, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=1200, model__replacement=True, model__sampling_strategy=0.5; total time=  29.2s
# [CV] END model__max_depth=8, model__max_features=0.5, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=1200, model__replacement=True, model__sampling_strategy=0.5; total time=  28.2s
# [CV] END model__max_depth=8, model__max_features=0.5, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=1200, model__replacement=True, model__sampling_strategy=0.5; total time=  28.4s
# [CV] END model__max_depth=8, model__max_features=0.5, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=1200, model__replacement=True, model__sampling_strategy=0.5; total time=  28.3s
# [CV] END model__max_depth=12, model__max_features=0.3, model__min_samples_leaf=8, model__min_samples_split=5, model__n_estimators=800, model__replacement=False, model__sampling_strategy=0.7; total time=  14.5s
# [CV] END model__max_depth=12, model__max_features=0.3, model__min_samples_leaf=8, model__min_samples_split=5, model__n_estimators=800, model__replacement=False, model__sampling_strategy=0.7; total time=  14.8s
# [CV] END model__max_depth=None, model__max_features=0.8, model__min_samples_leaf=12, model__min_samples_split=10, model__n_estimators=500, model__replacement=False, model__sampling_strategy=1.0; total time=  13.5s
# [CV] END model__max_depth=None, model__max_features=0.8, model__min_samples_leaf=12, model__min_samples_split=10, model__n_estimators=500, model__replacement=False, model__sampling_strategy=1.0; total time=  10.6s
# [CV] END model__max_depth=None, model__max_features=0.8, model__min_samples_leaf=12, model__min_samples_split=10, model__n_estimators=500, model__replacement=False, model__sampling_strategy=1.0; total time=  10.7s
# [CV] END model__max_depth=None, model__max_features=0.8, model__min_samples_leaf=12, model__min_samples_split=10, model__n_estimators=500, model__replacement=False, model__sampling_strategy=1.0; total time=  10.8s
# [CV] END model__max_depth=20, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=800, model__replacement=True, model__sampling_strategy=0.7; total time=  10.6s
# [CV] END model__max_depth=None, model__max_features=0.8, model__min_samples_leaf=12, model__min_samples_split=10, model__n_estimators=500, model__replacement=False, model__sampling_strategy=1.0; total time=  10.9s
# [CV] END model__max_depth=20, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=800, model__replacement=True, model__sampling_strategy=0.7; total time=  10.3s
# [CV] END model__max_depth=20, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=800, model__replacement=True, model__sampling_strategy=0.7; total time=  10.5s
# [CV] END model__max_depth=20, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=800, model__replacement=True, model__sampling_strategy=0.7; total time=  10.7s
# [CV] END model__max_depth=20, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=800, model__replacement=True, model__sampling_strategy=0.7; total time=   9.6s
# [CV] END model__max_depth=None, model__max_features=0.5, model__min_samples_leaf=8, model__min_samples_split=2, model__n_estimators=800, model__replacement=False, model__sampling_strategy=1.0; total time=  11.9s
# [CV] END model__max_depth=None, model__max_features=0.5, model__min_samples_leaf=8, model__min_samples_split=2, model__n_estimators=800, model__replacement=False, model__sampling_strategy=1.0; total time=  11.7s
# [CV] END model__max_depth=None, model__max_features=0.5, model__min_samples_leaf=8, model__min_samples_split=2, model__n_estimators=800, model__replacement=False, model__sampling_strategy=1.0; total time=  11.1s
# [CV] END model__max_depth=None, model__max_features=0.5, model__min_samples_leaf=8, model__min_samples_split=2, model__n_estimators=800, model__replacement=False, model__sampling_strategy=1.0; total time=  11.5s
# [CV] END model__max_depth=None, model__max_features=0.5, model__min_samples_leaf=8, model__min_samples_split=2, model__n_estimators=800, model__replacement=False, model__sampling_strategy=1.0; total time=  11.7s
# [CV] END model__max_depth=8, model__max_features=0.8, model__min_samples_leaf=4, model__min_samples_split=2, model__n_estimators=300, model__replacement=True, model__sampling_strategy=auto; total time=   5.2s
# [CV] END model__max_depth=8, model__max_features=0.8, model__min_samples_leaf=4, model__min_samples_split=2, model__n_estimators=300, model__replacement=True, model__sampling_strategy=auto; total time=   5.1s
# [CV] END model__max_depth=8, model__max_features=0.8, model__min_samples_leaf=4, model__min_samples_split=2, model__n_estimators=300, model__replacement=True, model__sampling_strategy=auto; total time=   5.3s
# [CV] END model__max_depth=8, model__max_features=0.8, model__min_samples_leaf=4, model__min_samples_split=2, model__n_estimators=300, model__replacement=True, model__sampling_strategy=auto; total time=   6.0s
# [CV] END model__max_depth=8, model__max_features=0.8, model__min_samples_leaf=4, model__min_samples_split=2, model__n_estimators=300, model__replacement=True, model__sampling_strategy=auto; total time=   6.3s
# [CV] END model__max_depth=12, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=800, model__replacement=False, model__sampling_strategy=0.7; total time=   8.8s
# [CV] END model__max_depth=None, model__max_features=0.8, model__min_samples_leaf=1, model__min_samples_split=10, model__n_estimators=1200, model__replacement=False, model__sampling_strategy=auto; total time=  25.8s
# [CV] END model__max_depth=None, model__max_features=0.8, model__min_samples_leaf=1, model__min_samples_split=10, model__n_estimators=1200, model__replacement=False, model__sampling_strategy=auto; total time=  25.7s
# [CV] END model__max_depth=20, model__max_features=0.5, model__min_samples_leaf=4, model__min_samples_split=2, model__n_estimators=300, model__replacement=True, model__sampling_strategy=0.7; total time=   5.7s
# [CV] END model__max_depth=12, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=800, model__replacement=False, model__sampling_strategy=0.7; total time=   9.7s
# [CV] END model__max_depth=12, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=800, model__replacement=False, model__sampling_strategy=0.7; total time=   9.4s
# [CV] END model__max_depth=None, model__max_features=0.8, model__min_samples_leaf=1, model__min_samples_split=10, model__n_estimators=1200, model__replacement=False, model__sampling_strategy=auto; total time=  26.0s
# [CV] END model__max_depth=12, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=800, model__replacement=False, model__sampling_strategy=0.7; total time=   9.8s
# [CV] END model__max_depth=None, model__max_features=0.8, model__min_samples_leaf=1, model__min_samples_split=10, model__n_estimators=1200, model__replacement=False, model__sampling_strategy=auto; total time=  26.1s
# [CV] END model__max_depth=12, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=800, model__replacement=False, model__sampling_strategy=0.7; total time=  10.0s
# [CV] END model__max_depth=None, model__max_features=0.8, model__min_samples_leaf=1, model__min_samples_split=10, model__n_estimators=1200, model__replacement=False, model__sampling_strategy=auto; total time=  25.5s
# [CV] END model__max_depth=20, model__max_features=0.5, model__min_samples_leaf=4, model__min_samples_split=2, model__n_estimators=300, model__replacement=True, model__sampling_strategy=0.7; total time=   4.8s
# [CV] END model__max_depth=20, model__max_features=0.5, model__min_samples_leaf=4, model__min_samples_split=2, model__n_estimators=300, model__replacement=True, model__sampling_strategy=0.7; total time=   4.9s
# [CV] END model__max_depth=20, model__max_features=0.5, model__min_samples_leaf=4, model__min_samples_split=2, model__n_estimators=300, model__replacement=True, model__sampling_strategy=0.7; total time=   4.8s
# [CV] END model__max_depth=20, model__max_features=0.5, model__min_samples_leaf=4, model__min_samples_split=2, model__n_estimators=300, model__replacement=True, model__sampling_strategy=0.7; total time=   4.7s
# [CV] END model__max_depth=12, model__max_features=0.8, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=800, model__replacement=False, model__sampling_strategy=0.5; total time=  18.8s
# [CV] END model__max_depth=12, model__max_features=0.8, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=800, model__replacement=False, model__sampling_strategy=0.5; total time=  19.8s
# [CV] END model__max_depth=12, model__max_features=0.8, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=800, model__replacement=False, model__sampling_strategy=0.5; total time=  19.4s
# [CV] END model__max_depth=12, model__max_features=0.8, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=800, model__replacement=False, model__sampling_strategy=0.5; total time=  19.6s
# [CV] END model__max_depth=12, model__max_features=0.8, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=800, model__replacement=False, model__sampling_strategy=0.5; total time=  19.2s
#
# Best CV PR-AUC: 0.7559602666233075
# Best params: {'model__sampling_strategy': 0.5, 'model__replacement': False, 'model__n_estimators': 300, 'model__min_samples_split': 5, 'model__min_samples_leaf': 1, 'model__max_features': 0.3, 'model__max_depth': 8}
#
# TEST PR-AUC : 0.7466332225549133
# TEST ROC-AUC: 0.9302589663454292
#
# Saved: artifacts/best_pr_auc_balancedrf.joblib
